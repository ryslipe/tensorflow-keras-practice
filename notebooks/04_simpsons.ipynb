# %% [markdown]
# ### Simpsons Example

# %%
import tensorflow as tf
from tensorflow import keras
import cv2
import os

# %%
# ensure we are working in the correct directory
os.chdir("c:/Users/ryans/Documents/tensorflow_keras_work")
print(os.getcwd())  # Confirm the change
# Out:
# c:\Users\ryans\Documents\tensorflow_keras_work

# %%
# image of Bart
image = cv2.imread(os.path.join('data', 'bart', 'bart10.bmp'))

# %%
import matplotlib.pyplot as plt
# plot the image
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
# view the shape
image.shape
# Out:
# (517, 369, 3)

# %%
# view an image of homer
image2 = cv2.imread(os.path.join('data', 'homer', 'homer1.bmp'))

# plot
plt.imshow(cv2.cvtColor(image2, cv2.COLOR_BGR2RGB))

# %%
image2.shape
# Out:
# (576, 237, 3)

# %% [markdown]
# #### Create a Dataset Similar to MNIST

# %%
# use keras utils to create a data set for us from our data folder
data = tf.keras.utils.image_dataset_from_directory('data')
# Out:
# Found 269 files belonging to 2 classes.

# %%
data
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
